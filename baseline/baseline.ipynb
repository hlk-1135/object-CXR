# %% [markdown]
# # Object CXR

# %%
import torch
import torchvision
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
import utils

from PIL import Image, ImageDraw
from engine import train_one_epoch
from sklearn.metrics import roc_auc_score
from tqdm import tqdm

# %%
np.random.seed(0)
torch.manual_seed(0)

# %%
OBJECT_SEP = ';'
ANNOTATION_SEP = ' '

# ─── DATA_PATH
#     ├── train
#     │   ├── #####.jpg
#     │   └── ...
#     ├── dev
#     │   ├── #####.jpg
#     │   └── ...
#     ├── train.csv
#     └── dev.csv
root = '<DATA_PATH>'

device = torch.device('cuda:0')
num_classes = 2  # object (foreground); background

# %%
def draw_annotation(im, anno_str, fill=(255, 0, 0, 30)):
    draw = ImageDraw.Draw(im, mode="RGBA")
    for anno in anno_str.split(OBJECT_SEP):
        anno = list(map(int, anno.split(ANNOTATION_SEP)))
        if anno[0] == 0:
            draw.rectangle(anno[1:], fill=fill)
        elif anno[0] == 1:
            draw.ellipse(anno[1:], fill=fill)
        else:
            draw.polygon(anno[1:], fill=fill)

# %% [markdown]
# ## Data

# %%
labels_tr = pd.read_csv(root + 'train.csv', na_filter=False)
labels_dev = pd.read_csv(root + 'dev.csv', na_filter=False)

print(f'{len(os.listdir(root + "train"))} pictures in {root}train/')
print(f'{len(os.listdir(root + "dev"))} pictures in {root}dev/')
print(f'{len(os.listdir(root + "test"))} pictures in {root}test/')

# viz
fig, axs = plt.subplots(
    nrows=1, ncols=4, subplot_kw=dict(xticks=[], yticks=[]), figsize=(24, 6)
)

# train_imgs = os.listdir(root + "train")
example_idxes = [58, 1850, 2611, 6213]
for row, ax in zip(
    labels_tr.iloc[example_idxes].itertuples(index=False), axs
):
    im = Image.open(root + "train/" + row.image_name).convert("RGB")
    if row.annotation:
        draw_annotation(im, row.annotation)
    
    ax.imshow(im)
    ax.set_title(f"{row.image_name}")
# Out:
# 8000 pictures in data/train/
# 1000 pictures in data/dev/
# 1000 pictures in data/test/

# %% [markdown]
# ## Build Dataset

# %%
labels_tr = labels_tr.loc[labels_tr['annotation'].astype(bool)].reset_index(drop=True)
img_class_dict_tr = dict(zip(labels_tr.image_name, labels_tr.annotation))
img_class_dict_dev = dict(zip(labels_dev.image_name, labels_dev.annotation))

# %%
class ForeignObjectDataset(object):
    
    def __init__(self, datafolder, datatype='train', transform = True, labels_dict={}):
        self.datafolder = datafolder
        self.datatype = datatype
        self.labels_dict = labels_dict
        self.image_files_list = [s for s in sorted(os.listdir(datafolder)) if s in labels_dict.keys()]
        self.transform = transform
        self.annotations = [labels_dict[i] for i in self.image_files_list]
            
    def __getitem__(self, idx):
        # load images 
        img_name = self.image_files_list[idx]
        img_path = os.path.join(self.datafolder, img_name)
        img = Image.open(img_path).convert("RGB")
        width, height = img.size[0],img.size[1]  
        
        if self.datatype == 'train':
            annotation = self.labels_dict[img_name]
            
            boxes = []
            
            if type(annotation) == str:
                annotation_list = annotation.split(';')
                for anno in annotation_list:
                    x = []
                    y = []
                
                    anno = anno[2:]
                    anno = anno.split(' ')
                    for i in range(len(anno)):
                        if i % 2 == 0:
                            x.append(float(anno[i]))
                        else:
                            y.append(float(anno[i]))
                        
                    xmin = min(x)/width * 600
                    xmax = max(x)/width * 600
                    ymin = min(y)/height * 600
                    ymax = max(y)/height * 600
                    boxes.append([xmin, ymin, xmax, ymax])

            # convert everything into a torch.Tensor
            boxes = torch.as_tensor(boxes, dtype=torch.float32)
            # there is only one class
            labels = torch.ones((len(boxes),), dtype=torch.int64)

            image_id = torch.tensor([idx])
            area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])
            # suppose all instances are not crowd
            iscrowd = torch.zeros((len(boxes),), dtype=torch.int64)

            target = {}
            target["boxes"] = boxes
            target["labels"] = labels
            target["image_id"] = image_id
            target["area"] = area
            target["iscrowd"] = iscrowd
            
            if self.transform is not None:
                img = self.transform(img)
                
            return img, target
        
        if self.datatype == 'dev':
            
            if self.labels_dict[img_name] == '':
                label = 0
            else:
                label = 1
            
            if self.transform is not None:
                img = self.transform(img)

            return img, label, width, height

        

    def __len__(self):
        return len(self.image_files_list)

# %%
import torchvision.transforms as transforms

data_transforms = transforms.Compose([
    transforms.Resize((600,600)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

dataset_train = ForeignObjectDataset(datafolder= root + 'train/', datatype='train', transform=data_transforms, labels_dict=img_class_dict_tr)
dataset_dev = ForeignObjectDataset(datafolder= root + 'dev/', datatype='dev', transform=data_transforms, labels_dict=img_class_dict_dev)

# %%
data_loader = torch.utils.data.DataLoader(
    dataset_train, batch_size=8, shuffle= True, num_workers=4,
    collate_fn=utils.collate_fn)

data_loader_val = torch.utils.data.DataLoader(
    dataset_dev, batch_size=1, shuffle= False, num_workers=4,
    collate_fn=utils.collate_fn)

# %% [markdown]
# ## Training

# %%
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

def _get_instance_segmentation_model(num_classes):
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)
    return model

# %%
model_ft = _get_instance_segmentation_model(num_classes)
model_ft.to(device)

params = [p for p in model_ft.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005,
                            momentum=0.9, weight_decay=0.0005)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                               step_size=5,
                                               gamma=0.1)

num_epochs = 7

auc_max = 0

for epoch in range(num_epochs):
    
    train_one_epoch(model_ft, optimizer, data_loader, device, epoch, print_freq=20)
    
    lr_scheduler.step()
    
    model_ft.eval()
    val_pred = []
    val_label = []
    for batch_i, (image, label,  width, height) in enumerate(data_loader_val):
        image = list(img.to(device) for img in image)
        
        val_label.append(label[-1])

        outputs = model_ft(image)
        if len(outputs[-1]['boxes']) == 0:
            val_pred.append(0)
        else:
            val_pred.append(torch.max(outputs[-1]['scores']).tolist())
    
    val_pred_label = []
    for i in range(len(val_pred)):
        if val_pred[i] >= 0.5:
            val_pred_label.append(1)
        else:
            val_pred_label.append(0)
            
    number = 0
    
    for i in range(len(val_pred_label)):
        if val_pred_label[i] == val_label[i]:
            number += 1
    acc = number / len(val_pred_label)
    
    auc = roc_auc_score(val_label,val_pred)
    print('Epoch: ', epoch, '| val acc: %.4f' % acc, '| val auc: %.4f' % auc)
    
    if auc > auc_max:
        auc_max = auc
        print('Best Epoch: ', epoch, '| val acc: %.4f' % acc, '| Best val auc: %.4f' % auc_max)
        torch.save(model_ft.state_dict(), "model.pt")
# Out:
# Epoch: [0]  [  0/500]  eta: 0:22:37  lr: 0.000015  loss: 2.0857 (2.0857)  loss_classifier: 1.5172 (1.5172)  loss_box_reg: 0.0053 (0.0053)  loss_objectness: 0.5428 (0.5428)  loss_rpn_box_reg: 0.0205 (0.0205)  time: 2.7143
# Epoch: [0]  [ 20/500]  eta: 0:07:51  lr: 0.000215  loss: 0.5464 (0.7670)  loss_classifier: 0.1682 (0.4540)  loss_box_reg: 0.0300 (0.0335)  loss_objectness: 0.1971 (0.2570)  loss_rpn_box_reg: 0.0185 (0.0225)  time: 0.8954
# Epoch: [0]  [ 40/500]  eta: 0:07:12  lr: 0.000415  loss: 0.3215 (0.5664)  loss_classifier: 0.1292 (0.2973)  loss_box_reg: 0.0448 (0.0408)  loss_objectness: 0.1439 (0.2052)  loss_rpn_box_reg: 0.0204 (0.0231)  time: 0.8960
# Epoch: [0]  [ 60/500]  eta: 0:06:47  lr: 0.000616  loss: 0.2468 (0.4659)  loss_classifier: 0.0983 (0.2343)  loss_box_reg: 0.0413 (0.0420)  loss_objectness: 0.0850 (0.1680)  loss_rpn_box_reg: 0.0173 (0.0216)  time: 0.8949
# Epoch: [0]  [ 80/500]  eta: 0:06:25  lr: 0.000816  loss: 0.2652 (0.4208)  loss_classifier: 0.1212 (0.2070)  loss_box_reg: 0.0601 (0.0474)  loss_objectness: 0.0705 (0.1456)  loss_rpn_box_reg: 0.0166 (0.0208)  time: 0.8961
# Epoch: [0]  [100/500]  eta: 0:06:05  lr: 0.001016  loss: 0.2834 (0.3996)  loss_classifier: 0.1320 (0.1935)  loss_box_reg: 0.0720 (0.0527)  loss_objectness: 0.0642 (0.1319)  loss_rpn_box_reg: 0.0169 (0.0215)  time: 0.8994
# Epoch: [0]  [120/500]  eta: 0:05:46  lr: 0.001216  loss: 0.2969 (0.3842)  loss_classifier: 0.1289 (0.1844)  loss_box_reg: 0.0754 (0.0577)  loss_objectness: 0.0671 (0.1215)  loss_rpn_box_reg: 0.0152 (0.0207)  time: 0.8968
# Epoch: [0]  [140/500]  eta: 0:05:27  lr: 0.001416  loss: 0.2883 (0.3721)  loss_classifier: 0.1288 (0.1777)  loss_box_reg: 0.0763 (0.0610)  loss_objectness: 0.0593 (0.1136)  loss_rpn_box_reg: 0.0133 (0.0198)  time: 0.8974
# Epoch: [0]  [160/500]  eta: 0:05:08  lr: 0.001617  loss: 0.3154 (0.3655)  loss_classifier: 0.1449 (0.1737)  loss_box_reg: 0.0881 (0.0648)  loss_objectness: 0.0524 (0.1070)  loss_rpn_box_reg: 0.0120 (0.0200)  time: 0.8992
# Epoch: [0]  [180/500]  eta: 0:04:50  lr: 0.001817  loss: 0.2896 (0.3576)  loss_classifier: 0.1344 (0.1694)  loss_box_reg: 0.0872 (0.0671)  loss_objectness: 0.0518 (0.1014)  loss_rpn_box_reg: 0.0135 (0.0197)  time: 0.9024
# Epoch: [0]  [200/500]  eta: 0:04:31  lr: 0.002017  loss: 0.2943 (0.3544)  loss_classifier: 0.1364 (0.1671)  loss_box_reg: 0.0938 (0.0710)  loss_objectness: 0.0469 (0.0968)  loss_rpn_box_reg: 0.0147 (0.0195)  time: 0.8954
# Epoch: [0]  [220/500]  eta: 0:04:13  lr: 0.002217  loss: 0.3014 (0.3512)  loss_classifier: 0.1368 (0.1653)  loss_box_reg: 0.0980 (0.0736)  loss_objectness: 0.0541 (0.0929)  loss_rpn_box_reg: 0.0162 (0.0194)  time: 0.8990
# Epoch: [0]  [240/500]  eta: 0:03:55  lr: 0.002417  loss: 0.2677 (0.3483)  loss_classifier: 0.1313 (0.1637)  loss_box_reg: 0.0857 (0.0755)  loss_objectness: 0.0391 (0.0899)  loss_rpn_box_reg: 0.0155 (0.0193)  time: 0.8964
# Epoch: [0]  [260/500]  eta: 0:03:37  lr: 0.002618  loss: 0.2678 (0.3435)  loss_classifier: 0.1175 (0.1604)  loss_box_reg: 0.0713 (0.0754)  loss_objectness: 0.0431 (0.0884)  loss_rpn_box_reg: 0.0132 (0.0194)  time: 0.8992
# Epoch: [0]  [280/500]  eta: 0:03:18  lr: 0.002818  loss: 0.2804 (0.3397)  loss_classifier: 0.1381 (0.1588)  loss_box_reg: 0.0857 (0.0762)  loss_objectness: 0.0450 (0.0856)  loss_rpn_box_reg: 0.0144 (0.0191)  time: 0.9011
# Epoch: [0]  [300/500]  eta: 0:03:00  lr: 0.003018  loss: 0.2769 (0.3358)  loss_classifier: 0.1287 (0.1571)  loss_box_reg: 0.0835 (0.0768)  loss_objectness: 0.0373 (0.0830)  loss_rpn_box_reg: 0.0147 (0.0189)  time: 0.8995
# Epoch: [0]  [320/500]  eta: 0:02:42  lr: 0.003218  loss: 0.2793 (0.3334)  loss_classifier: 0.1347 (0.1562)  loss_box_reg: 0.0884 (0.0779)  loss_objectness: 0.0395 (0.0806)  loss_rpn_box_reg: 0.0143 (0.0187)  time: 0.9003
# Epoch: [0]  [340/500]  eta: 0:02:24  lr: 0.003418  loss: 0.3032 (0.3322)  loss_classifier: 0.1421 (0.1559)  loss_box_reg: 0.0974 (0.0795)  loss_objectness: 0.0376 (0.0784)  loss_rpn_box_reg: 0.0131 (0.0184)  time: 0.9027
# Epoch: [0]  [360/500]  eta: 0:02:06  lr: 0.003619  loss: 0.2576 (0.3289)  loss_classifier: 0.1323 (0.1549)  loss_box_reg: 0.0876 (0.0799)  loss_objectness: 0.0283 (0.0760)  loss_rpn_box_reg: 0.0114 (0.0181)  time: 0.9013
# Epoch: [0]  [380/500]  eta: 0:01:48  lr: 0.003819  loss: 0.2624 (0.3260)  loss_classifier: 0.1284 (0.1538)  loss_box_reg: 0.0852 (0.0803)  loss_objectness: 0.0353 (0.0740)  loss_rpn_box_reg: 0.0123 (0.0179)  time: 0.9025
# Epoch: [0]  [400/500]  eta: 0:01:30  lr: 0.004019  loss: 0.2853 (0.3235)  loss_classifier: 0.1413 (0.1529)  loss_box_reg: 0.0924 (0.0808)  loss_objectness: 0.0291 (0.0721)  loss_rpn_box_reg: 0.0114 (0.0177)  time: 0.9039
# Epoch: [0]  [420/500]  eta: 0:01:12  lr: 0.004219  loss: 0.2447 (0.3210)  loss_classifier: 0.1220 (0.1516)  loss_box_reg: 0.0874 (0.0811)  loss_objectness: 0.0342 (0.0705)  loss_rpn_box_reg: 0.0139 (0.0177)  time: 0.9004
# Epoch: [0]  [440/500]  eta: 0:00:54  lr: 0.004419  loss: 0.2889 (0.3205)  loss_classifier: 0.1298 (0.1508)  loss_box_reg: 0.0892 (0.0815)  loss_objectness: 0.0427 (0.0704)  loss_rpn_box_reg: 0.0139 (0.0178)  time: 0.9006
# Epoch: [0]  [460/500]  eta: 0:00:36  lr: 0.004620  loss: 0.2813 (0.3184)  loss_classifier: 0.1362 (0.1501)  loss_box_reg: 0.0889 (0.0817)  loss_objectness: 0.0330 (0.0689)  loss_rpn_box_reg: 0.0141 (0.0177)  time: 0.8983
# Epoch: [0]  [480/500]  eta: 0:00:18  lr: 0.004820  loss: 0.2697 (0.3159)  loss_classifier: 0.1209 (0.1491)  loss_box_reg: 0.0831 (0.0819)  loss_objectness: 0.0272 (0.0674)  loss_rpn_box_reg: 0.0120 (0.0175)  time: 0.9018
# Epoch: [0]  [499/500]  eta: 0:00:00  lr: 0.005000  loss: 0.2840 (0.3150)  loss_classifier: 0.1390 (0.1488)  loss_box_reg: 0.0886 (0.0822)  loss_objectness: 0.0321 (0.0666)  loss_rpn_box_reg: 0.0129 (0.0175)  time: 0.8996
# Epoch: [0] Total time: 0:07:31 (0.9031 s / it)
# Epoch:  0 | val acc: 0.7370 | val auc: 0.8440
# Best Epoch:  0 | val acc: 0.7370 | Best val auc: 0.8440
# Epoch: [1]  [  0/500]  eta: 0:17:18  lr: 0.005000  loss: 0.2478 (0.2478)  loss_classifier: 0.1215 (0.1215)  loss_box_reg: 0.0790 (0.0790)  loss_objectness: 0.0393 (0.0393)  loss_rpn_box_reg: 0.0080 (0.0080)  time: 2.0761
# Epoch: [1]  [ 20/500]  eta: 0:07:41  lr: 0.005000  loss: 0.2169 (0.2365)  loss_classifier: 0.1081 (0.1160)  loss_box_reg: 0.0749 (0.0800)  loss_objectness: 0.0259 (0.0282)  loss_rpn_box_reg: 0.0120 (0.0123)  time: 0.9064
# Epoch: [1]  [ 40/500]  eta: 0:07:10  lr: 0.005000  loss: 0.2595 (0.2483)  loss_classifier: 0.1161 (0.1190)  loss_box_reg: 0.0769 (0.0811)  loss_objectness: 0.0335 (0.0338)  loss_rpn_box_reg: 0.0134 (0.0144)  time: 0.9067
# Epoch: [1]  [ 60/500]  eta: 0:06:46  lr: 0.005000  loss: 0.2466 (0.2492)  loss_classifier: 0.1227 (0.1201)  loss_box_reg: 0.0851 (0.0839)  loss_objectness: 0.0235 (0.0311)  loss_rpn_box_reg: 0.0137 (0.0142)  time: 0.9039
# Epoch: [1]  [ 80/500]  eta: 0:06:25  lr: 0.005000  loss: 0.2446 (0.2517)  loss_classifier: 0.1149 (0.1202)  loss_box_reg: 0.0839 (0.0836)  loss_objectness: 0.0275 (0.0325)  loss_rpn_box_reg: 0.0123 (0.0154)  time: 0.8996
# Epoch: [1]  [100/500]  eta: 0:06:06  lr: 0.005000  loss: 0.2368 (0.2521)  loss_classifier: 0.1103 (0.1200)  loss_box_reg: 0.0838 (0.0846)  loss_objectness: 0.0241 (0.0317)  loss_rpn_box_reg: 0.0144 (0.0158)  time: 0.9055
# Epoch: [1]  [120/500]  eta: 0:05:47  lr: 0.005000  loss: 0.2423 (0.2515)  loss_classifier: 0.1183 (0.1199)  loss_box_reg: 0.0832 (0.0846)  loss_objectness: 0.0268 (0.0314)  loss_rpn_box_reg: 0.0130 (0.0156)  time: 0.9044
# Epoch: [1]  [140/500]  eta: 0:05:28  lr: 0.005000  loss: 0.2348 (0.2526)  loss_classifier: 0.1196 (0.1216)  loss_box_reg: 0.0814 (0.0854)  loss_objectness: 0.0250 (0.0306)  loss_rpn_box_reg: 0.0108 (0.0150)  time: 0.9029
# Epoch: [1]  [160/500]  eta: 0:05:09  lr: 0.005000  loss: 0.2246 (0.2506)  loss_classifier: 0.1145 (0.1215)  loss_box_reg: 0.0688 (0.0845)  loss_objectness: 0.0228 (0.0301)  loss_rpn_box_reg: 0.0113 (0.0146)  time: 0.9061
# Epoch: [1]  [180/500]  eta: 0:04:51  lr: 0.005000  loss: 0.2482 (0.2492)  loss_classifier: 0.1067 (0.1203)  loss_box_reg: 0.0837 (0.0841)  loss_objectness: 0.0286 (0.0302)  loss_rpn_box_reg: 0.0140 (0.0146)  time: 0.9057
# Epoch: [1]  [200/500]  eta: 0:04:33  lr: 0.005000  loss: 0.2195 (0.2478)  loss_classifier: 0.1116 (0.1197)  loss_box_reg: 0.0804 (0.0840)  loss_objectness: 0.0236 (0.0296)  loss_rpn_box_reg: 0.0125 (0.0145)  time: 0.9060
# Epoch: [1]  [220/500]  eta: 0:04:14  lr: 0.005000  loss: 0.2229 (0.2478)  loss_classifier: 0.1122 (0.1201)  loss_box_reg: 0.0809 (0.0840)  loss_objectness: 0.0254 (0.0294)  loss_rpn_box_reg: 0.0120 (0.0143)  time: 0.9054
# Epoch: [1]  [240/500]  eta: 0:03:56  lr: 0.005000  loss: 0.2305 (0.2465)  loss_classifier: 0.1135 (0.1194)  loss_box_reg: 0.0771 (0.0836)  loss_objectness: 0.0238 (0.0294)  loss_rpn_box_reg: 0.0106 (0.0142)  time: 0.9039
# Epoch: [1]  [260/500]  eta: 0:03:38  lr: 0.005000  loss: 0.2786 (0.2491)  loss_classifier: 0.1234 (0.1203)  loss_box_reg: 0.0933 (0.0840)  loss_objectness: 0.0291 (0.0305)  loss_rpn_box_reg: 0.0127 (0.0143)  time: 0.9045
# Epoch: [1]  [280/500]  eta: 0:03:19  lr: 0.005000  loss: 0.2421 (0.2501)  loss_classifier: 0.1181 (0.1204)  loss_box_reg: 0.0760 (0.0841)  loss_objectness: 0.0352 (0.0311)  loss_rpn_box_reg: 0.0129 (0.0146)  time: 0.9005
# Epoch: [1]  [300/500]  eta: 0:03:01  lr: 0.005000  loss: 0.2262 (0.2493)  loss_classifier: 0.1163 (0.1203)  loss_box_reg: 0.0856 (0.0840)  loss_objectness: 0.0229 (0.0307)  loss_rpn_box_reg: 0.0104 (0.0144)  time: 0.9021
# Epoch: [1]  [320/500]  eta: 0:02:43  lr: 0.005000  loss: 0.2481 (0.2496)  loss_classifier: 0.1245 (0.1208)  loss_box_reg: 0.0920 (0.0844)  loss_objectness: 0.0217 (0.0302)  loss_rpn_box_reg: 0.0113 (0.0142)  time: 0.9048
# Epoch: [1]  [340/500]  eta: 0:02:25  lr: 0.005000  loss: 0.2433 (0.2497)  loss_classifier: 0.1230 (0.1213)  loss_box_reg: 0.0783 (0.0843)  loss_objectness: 0.0217 (0.0299)  loss_rpn_box_reg: 0.0105 (0.0141)  time: 0.9012
# Epoch: [1]  [360/500]  eta: 0:02:07  lr: 0.005000  loss: 0.2692 (0.2510)  loss_classifier: 0.1303 (0.1219)  loss_box_reg: 0.0872 (0.0844)  loss_objectness: 0.0346 (0.0305)  loss_rpn_box_reg: 0.0138 (0.0142)  time: 0.9056
# Epoch: [1]  [380/500]  eta: 0:01:48  lr: 0.005000  loss: 0.2447 (0.2504)  loss_classifier: 0.1189 (0.1217)  loss_box_reg: 0.0792 (0.0843)  loss_objectness: 0.0238 (0.0303)  loss_rpn_box_reg: 0.0126 (0.0141)  time: 0.9031
# Epoch: [1]  [400/500]  eta: 0:01:30  lr: 0.005000  loss: 0.2475 (0.2506)  loss_classifier: 0.1204 (0.1219)  loss_box_reg: 0.0834 (0.0845)  loss_objectness: 0.0187 (0.0301)  loss_rpn_box_reg: 0.0121 (0.0141)  time: 0.9045
# Epoch: [1]  [420/500]  eta: 0:01:12  lr: 0.005000  loss: 0.2505 (0.2517)  loss_classifier: 0.1283 (0.1223)  loss_box_reg: 0.0848 (0.0850)  loss_objectness: 0.0221 (0.0304)  loss_rpn_box_reg: 0.0123 (0.0141)  time: 0.9041
# Epoch: [1]  [440/500]  eta: 0:00:54  lr: 0.005000  loss: 0.2243 (0.2506)  loss_classifier: 0.1109 (0.1218)  loss_box_reg: 0.0762 (0.0845)  loss_objectness: 0.0269 (0.0303)  loss_rpn_box_reg: 0.0115 (0.0140)  time: 0.9032
# Epoch: [1]  [460/500]  eta: 0:00:36  lr: 0.005000  loss: 0.2509 (0.2510)  loss_classifier: 0.1219 (0.1218)  loss_box_reg: 0.0798 (0.0845)  loss_objectness: 0.0294 (0.0305)  loss_rpn_box_reg: 0.0122 (0.0141)  time: 0.9040
# Epoch: [1]  [480/500]  eta: 0:00:18  lr: 0.005000  loss: 0.2179 (0.2501)  loss_classifier: 0.1056 (0.1214)  loss_box_reg: 0.0799 (0.0844)  loss_objectness: 0.0194 (0.0303)  loss_rpn_box_reg: 0.0119 (0.0140)  time: 0.9068
# Epoch: [1]  [499/500]  eta: 0:00:00  lr: 0.005000  loss: 0.2315 (0.2500)  loss_classifier: 0.1133 (0.1215)  loss_box_reg: 0.0864 (0.0844)  loss_objectness: 0.0218 (0.0301)  loss_rpn_box_reg: 0.0121 (0.0140)  time: 0.9011
# Epoch: [1] Total time: 0:07:33 (0.9068 s / it)
# Epoch:  1 | val acc: 0.7190 | val auc: 0.9066
# Best Epoch:  1 | val acc: 0.7190 | Best val auc: 0.9066
# Epoch: [2]  [  0/500]  eta: 0:18:48  lr: 0.005000  loss: 0.2340 (0.2340)  loss_classifier: 0.1158 (0.1158)  loss_box_reg: 0.0899 (0.0899)  loss_objectness: 0.0170 (0.0170)  loss_rpn_box_reg: 0.0114 (0.0114)  time: 2.2577
# Epoch: [2]  [ 20/500]  eta: 0:07:46  lr: 0.005000  loss: 0.2238 (0.2326)  loss_classifier: 0.1070 (0.1186)  loss_box_reg: 0.0801 (0.0820)  loss_objectness: 0.0153 (0.0202)  loss_rpn_box_reg: 0.0118 (0.0118)  time: 0.9081
# Epoch: [2]  [ 40/500]  eta: 0:07:12  lr: 0.005000  loss: 0.2464 (0.2372)  loss_classifier: 0.1222 (0.1186)  loss_box_reg: 0.0822 (0.0813)  loss_objectness: 0.0197 (0.0244)  loss_rpn_box_reg: 0.0123 (0.0130)  time: 0.9056
# Epoch: [2]  [ 60/500]  eta: 0:06:48  lr: 0.005000  loss: 0.2478 (0.2391)  loss_classifier: 0.1232 (0.1195)  loss_box_reg: 0.0839 (0.0827)  loss_objectness: 0.0214 (0.0241)  loss_rpn_box_reg: 0.0132 (0.0128)  time: 0.9061
# Epoch: [2]  [ 80/500]  eta: 0:06:27  lr: 0.005000  loss: 0.2337 (0.2367)  loss_classifier: 0.1163 (0.1180)  loss_box_reg: 0.0727 (0.0823)  loss_objectness: 0.0204 (0.0233)  loss_rpn_box_reg: 0.0119 (0.0131)  time: 0.9078
# Epoch: [2]  [100/500]  eta: 0:06:07  lr: 0.005000  loss: 0.2366 (0.2392)  loss_classifier: 0.1180 (0.1186)  loss_box_reg: 0.0891 (0.0841)  loss_objectness: 0.0175 (0.0233)  loss_rpn_box_reg: 0.0114 (0.0132)  time: 0.9020
# Epoch: [2]  [120/500]  eta: 0:05:48  lr: 0.005000  loss: 0.2371 (0.2407)  loss_classifier: 0.1189 (0.1194)  loss_box_reg: 0.0864 (0.0846)  loss_objectness: 0.0214 (0.0236)  loss_rpn_box_reg: 0.0122 (0.0131)  time: 0.9029
# Epoch: [2]  [140/500]  eta: 0:05:29  lr: 0.005000  loss: 0.2213 (0.2373)  loss_classifier: 0.1080 (0.1179)  loss_box_reg: 0.0820 (0.0835)  loss_objectness: 0.0155 (0.0229)  loss_rpn_box_reg: 0.0116 (0.0129)  time: 0.9058
# Epoch: [2]  [160/500]  eta: 0:05:10  lr: 0.005000  loss: 0.2346 (0.2376)  loss_classifier: 0.1202 (0.1183)  loss_box_reg: 0.0834 (0.0837)  loss_objectness: 0.0186 (0.0228)  loss_rpn_box_reg: 0.0121 (0.0127)  time: 0.9061
# Epoch: [2]  [180/500]  eta: 0:04:52  lr: 0.005000  loss: 0.2274 (0.2373)  loss_classifier: 0.1179 (0.1184)  loss_box_reg: 0.0814 (0.0839)  loss_objectness: 0.0170 (0.0224)  loss_rpn_box_reg: 0.0106 (0.0126)  time: 0.9026
# Epoch: [2]  [200/500]  eta: 0:04:33  lr: 0.005000  loss: 0.2344 (0.2370)  loss_classifier: 0.1149 (0.1187)  loss_box_reg: 0.0824 (0.0840)  loss_objectness: 0.0147 (0.0218)  loss_rpn_box_reg: 0.0103 (0.0125)  time: 0.9050
# Epoch: [2]  [220/500]  eta: 0:04:15  lr: 0.005000  loss: 0.2600 (0.2387)  loss_classifier: 0.1199 (0.1193)  loss_box_reg: 0.0868 (0.0842)  loss_objectness: 0.0204 (0.0225)  loss_rpn_box_reg: 0.0118 (0.0127)  time: 0.9066
# Epoch: [2]  [240/500]  eta: 0:03:56  lr: 0.005000  loss: 0.2164 (0.2404)  loss_classifier: 0.1076 (0.1195)  loss_box_reg: 0.0795 (0.0841)  loss_objectness: 0.0223 (0.0232)  loss_rpn_box_reg: 0.0120 (0.0135)  time: 0.9039
# Epoch: [2]  [260/500]  eta: 0:03:38  lr: 0.005000  loss: 0.2195 (0.2391)  loss_classifier: 0.1094 (0.1187)  loss_box_reg: 0.0781 (0.0838)  loss_objectness: 0.0166 (0.0231)  loss_rpn_box_reg: 0.0108 (0.0135)  time: 0.9047
# Epoch: [2]  [280/500]  eta: 0:03:20  lr: 0.005000  loss: 0.2266 (0.2387)  loss_classifier: 0.1112 (0.1184)  loss_box_reg: 0.0818 (0.0838)  loss_objectness: 0.0172 (0.0231)  loss_rpn_box_reg: 0.0132 (0.0135)  time: 0.9024
# Epoch: [2]  [300/500]  eta: 0:03:01  lr: 0.005000  loss: 0.2432 (0.2388)  loss_classifier: 0.1184 (0.1186)  loss_box_reg: 0.0887 (0.0839)  loss_objectness: 0.0181 (0.0229)  loss_rpn_box_reg: 0.0103 (0.0134)  time: 0.9037
# Epoch: [2]  [320/500]  eta: 0:02:43  lr: 0.005000  loss: 0.2347 (0.2390)  loss_classifier: 0.1186 (0.1185)  loss_box_reg: 0.0894 (0.0844)  loss_objectness: 0.0191 (0.0229)  loss_rpn_box_reg: 0.0110 (0.0133)  time: 0.9050
# Epoch: [2]  [340/500]  eta: 0:02:25  lr: 0.005000  loss: 0.2361 (0.2389)  loss_classifier: 0.1155 (0.1186)  loss_box_reg: 0.0869 (0.0844)  loss_objectness: 0.0183 (0.0227)  loss_rpn_box_reg: 0.0115 (0.0132)  time: 0.9066
# Epoch: [2]  [360/500]  eta: 0:02:07  lr: 0.005000  loss: 0.2096 (0.2390)  loss_classifier: 0.1133 (0.1186)  loss_box_reg: 0.0812 (0.0845)  loss_objectness: 0.0201 (0.0227)  loss_rpn_box_reg: 0.0104 (0.0132)  time: 0.9058
# Epoch: [2]  [380/500]  eta: 0:01:49  lr: 0.005000  loss: 0.2412 (0.2390)  loss_classifier: 0.1151 (0.1187)  loss_box_reg: 0.0777 (0.0843)  loss_objectness: 0.0199 (0.0229)  loss_rpn_box_reg: 0.0114 (0.0131)  time: 0.9054
# Epoch: [2]  [400/500]  eta: 0:01:30  lr: 0.005000  loss: 0.2255 (0.2383)  loss_classifier: 0.1077 (0.1182)  loss_box_reg: 0.0806 (0.0843)  loss_objectness: 0.0152 (0.0227)  loss_rpn_box_reg: 0.0093 (0.0130)  time: 0.9044
# Epoch: [2]  [420/500]  eta: 0:01:12  lr: 0.005000  loss: 0.2185 (0.2380)  loss_classifier: 0.1154 (0.1182)  loss_box_reg: 0.0840 (0.0842)  loss_objectness: 0.0142 (0.0227)  loss_rpn_box_reg: 0.0106 (0.0129)  time: 0.9047
# Epoch: [2]  [440/500]  eta: 0:00:54  lr: 0.005000  loss: 0.2122 (0.2370)  loss_classifier: 0.1065 (0.1176)  loss_box_reg: 0.0771 (0.0839)  loss_objectness: 0.0189 (0.0227)  loss_rpn_box_reg: 0.0109 (0.0129)  time: 0.9080
# Epoch: [2]  [460/500]  eta: 0:00:36  lr: 0.005000  loss: 0.2211 (0.2372)  loss_classifier: 0.1050 (0.1172)  loss_box_reg: 0.0745 (0.0834)  loss_objectness: 0.0250 (0.0233)  loss_rpn_box_reg: 0.0137 (0.0132)  time: 0.9025
# Epoch: [2]  [480/500]  eta: 0:00:18  lr: 0.005000  loss: 0.2128 (0.2363)  loss_classifier: 0.1117 (0.1169)  loss_box_reg: 0.0716 (0.0831)  loss_objectness: 0.0168 (0.0233)  loss_rpn_box_reg: 0.0099 (0.0131)  time: 0.9049
# Epoch: [2]  [499/500]  eta: 0:00:00  lr: 0.005000  loss: 0.2388 (0.2362)  loss_classifier: 0.1217 (0.1169)  loss_box_reg: 0.0827 (0.0831)  loss_objectness: 0.0205 (0.0232)  loss_rpn_box_reg: 0.0105 (0.0130)  time: 0.9039
# Epoch: [2] Total time: 0:07:33 (0.9080 s / it)
# Epoch:  2 | val acc: 0.7570 | val auc: 0.9163
# Best Epoch:  2 | val acc: 0.7570 | Best val auc: 0.9163
# Epoch: [3]  [  0/500]  eta: 0:17:45  lr: 0.005000  loss: 0.2110 (0.2110)  loss_classifier: 0.1089 (0.1089)  loss_box_reg: 0.0618 (0.0618)  loss_objectness: 0.0311 (0.0311)  loss_rpn_box_reg: 0.0092 (0.0092)  time: 2.1304
# Epoch: [3]  [ 20/500]  eta: 0:07:44  lr: 0.005000  loss: 0.2154 (0.2186)  loss_classifier: 0.1052 (0.1102)  loss_box_reg: 0.0861 (0.0818)  loss_objectness: 0.0128 (0.0163)  loss_rpn_box_reg: 0.0101 (0.0103)  time: 0.9104
# Epoch: [3]  [ 40/500]  eta: 0:07:11  lr: 0.005000  loss: 0.2114 (0.2175)  loss_classifier: 0.1099 (0.1083)  loss_box_reg: 0.0831 (0.0803)  loss_objectness: 0.0172 (0.0176)  loss_rpn_box_reg: 0.0121 (0.0113)  time: 0.9080
# Epoch: [3]  [ 60/500]  eta: 0:06:48  lr: 0.005000  loss: 0.2110 (0.2193)  loss_classifier: 0.1026 (0.1095)  loss_box_reg: 0.0810 (0.0812)  loss_objectness: 0.0164 (0.0173)  loss_rpn_box_reg: 0.0109 (0.0114)  time: 0.9072
# Epoch: [3]  [ 80/500]  eta: 0:06:27  lr: 0.005000  loss: 0.2210 (0.2224)  loss_classifier: 0.1056 (0.1097)  loss_box_reg: 0.0811 (0.0812)  loss_objectness: 0.0163 (0.0186)  loss_rpn_box_reg: 0.0102 (0.0130)  time: 0.9075
# Epoch: [3]  [100/500]  eta: 0:06:08  lr: 0.005000  loss: 0.1996 (0.2196)  loss_classifier: 0.0984 (0.1086)  loss_box_reg: 0.0771 (0.0802)  loss_objectness: 0.0126 (0.0183)  loss_rpn_box_reg: 0.0096 (0.0125)  time: 0.9073
# Epoch: [3]  [120/500]  eta: 0:05:48  lr: 0.005000  loss: 0.2170 (0.2213)  loss_classifier: 0.1046 (0.1093)  loss_box_reg: 0.0761 (0.0801)  loss_objectness: 0.0157 (0.0188)  loss_rpn_box_reg: 0.0116 (0.0131)  time: 0.9044
# Epoch: [3]  [140/500]  eta: 0:05:29  lr: 0.005000  loss: 0.2337 (0.2215)  loss_classifier: 0.1127 (0.1092)  loss_box_reg: 0.0761 (0.0802)  loss_objectness: 0.0167 (0.0191)  loss_rpn_box_reg: 0.0116 (0.0131)  time: 0.9051
# Epoch: [3]  [160/500]  eta: 0:05:11  lr: 0.005000  loss: 0.2427 (0.2236)  loss_classifier: 0.1087 (0.1103)  loss_box_reg: 0.0808 (0.0805)  loss_objectness: 0.0185 (0.0197)  loss_rpn_box_reg: 0.0102 (0.0131)  time: 0.9092
# Epoch: [3]  [180/500]  eta: 0:04:52  lr: 0.005000  loss: 0.1976 (0.2221)  loss_classifier: 0.0978 (0.1094)  loss_box_reg: 0.0725 (0.0799)  loss_objectness: 0.0143 (0.0195)  loss_rpn_box_reg: 0.0102 (0.0132)  time: 0.9065
# Epoch: [3]  [200/500]  eta: 0:04:33  lr: 0.005000  loss: 0.2160 (0.2218)  loss_classifier: 0.1097 (0.1095)  loss_box_reg: 0.0811 (0.0800)  loss_objectness: 0.0138 (0.0192)  loss_rpn_box_reg: 0.0105 (0.0131)  time: 0.9060
# Epoch: [3]  [220/500]  eta: 0:04:15  lr: 0.005000  loss: 0.2056 (0.2213)  loss_classifier: 0.1128 (0.1096)  loss_box_reg: 0.0708 (0.0799)  loss_objectness: 0.0140 (0.0190)  loss_rpn_box_reg: 0.0097 (0.0129)  time: 0.9068
# Epoch: [3]  [240/500]  eta: 0:03:57  lr: 0.005000  loss: 0.2001 (0.2210)  loss_classifier: 0.1072 (0.1098)  loss_box_reg: 0.0674 (0.0793)  loss_objectness: 0.0173 (0.0191)  loss_rpn_box_reg: 0.0101 (0.0128)  time: 0.9069
# Epoch: [3]  [260/500]  eta: 0:03:38  lr: 0.005000  loss: 0.2108 (0.2208)  loss_classifier: 0.1063 (0.1101)  loss_box_reg: 0.0749 (0.0789)  loss_objectness: 0.0183 (0.0191)  loss_rpn_box_reg: 0.0109 (0.0127)  time: 0.9041
# Epoch: [3]  [280/500]  eta: 0:03:20  lr: 0.005000  loss: 0.2197 (0.2214)  loss_classifier: 0.1065 (0.1101)  loss_box_reg: 0.0752 (0.0790)  loss_objectness: 0.0195 (0.0194)  loss_rpn_box_reg: 0.0105 (0.0129)  time: 0.9058
# Epoch: [3]  [300/500]  eta: 0:03:02  lr: 0.005000  loss: 0.2125 (0.2213)  loss_classifier: 0.1129 (0.1103)  loss_box_reg: 0.0792 (0.0789)  loss_objectness: 0.0167 (0.0193)  loss_rpn_box_reg: 0.0091 (0.0127)  time: 0.9062
# Epoch: [3]  [320/500]  eta: 0:02:43  lr: 0.005000  loss: 0.1999 (0.2205)  loss_classifier: 0.0980 (0.1099)  loss_box_reg: 0.0704 (0.0788)  loss_objectness: 0.0154 (0.0192)  loss_rpn_box_reg: 0.0096 (0.0127)  time: 0.9035
# Epoch: [3]  [340/500]  eta: 0:02:25  lr: 0.005000  loss: 0.2097 (0.2206)  loss_classifier: 0.0983 (0.1097)  loss_box_reg: 0.0820 (0.0791)  loss_objectness: 0.0134 (0.0191)  loss_rpn_box_reg: 0.0113 (0.0127)  time: 0.9034
# Epoch: [3]  [360/500]  eta: 0:02:07  lr: 0.005000  loss: 0.2225 (0.2204)  loss_classifier: 0.1081 (0.1095)  loss_box_reg: 0.0795 (0.0791)  loss_objectness: 0.0164 (0.0191)  loss_rpn_box_reg: 0.0098 (0.0126)  time: 0.9075
# Epoch: [3]  [380/500]  eta: 0:01:49  lr: 0.005000  loss: 0.2228 (0.2211)  loss_classifier: 0.1083 (0.1100)  loss_box_reg: 0.0856 (0.0795)  loss_objectness: 0.0171 (0.0190)  loss_rpn_box_reg: 0.0106 (0.0126)  time: 0.9062
# Epoch: [3]  [400/500]  eta: 0:01:30  lr: 0.005000  loss: 0.2097 (0.2216)  loss_classifier: 0.1078 (0.1101)  loss_box_reg: 0.0790 (0.0796)  loss_objectness: 0.0173 (0.0193)  loss_rpn_box_reg: 0.0104 (0.0126)  time: 0.9055
# Epoch: [3]  [420/500]  eta: 0:01:12  lr: 0.005000  loss: 0.2154 (0.2213)  loss_classifier: 0.1099 (0.1100)  loss_box_reg: 0.0769 (0.0797)  loss_objectness: 0.0137 (0.0191)  loss_rpn_box_reg: 0.0102 (0.0125)  time: 0.9039
# Epoch: [3]  [440/500]  eta: 0:00:54  lr: 0.005000  loss: 0.2203 (0.2216)  loss_classifier: 0.1067 (0.1101)  loss_box_reg: 0.0890 (0.0800)  loss_objectness: 0.0139 (0.0190)  loss_rpn_box_reg: 0.0118 (0.0125)  time: 0.9076
# Epoch: [3]  [460/500]  eta: 0:00:36  lr: 0.005000  loss: 0.2558 (0.2227)  loss_classifier: 0.1305 (0.1109)  loss_box_reg: 0.0848 (0.0801)  loss_objectness: 0.0193 (0.0191)  loss_rpn_box_reg: 0.0135 (0.0126)  time: 0.9123
# Epoch: [3]  [480/500]  eta: 0:00:18  lr: 0.005000  loss: 0.2251 (0.2236)  loss_classifier: 0.1142 (0.1114)  loss_box_reg: 0.0836 (0.0806)  loss_objectness: 0.0174 (0.0191)  loss_rpn_box_reg: 0.0110 (0.0126)  time: 0.9077
# Epoch: [3]  [499/500]  eta: 0:00:00  lr: 0.005000  loss: 0.1977 (0.2231)  loss_classifier: 0.1019 (0.1111)  loss_box_reg: 0.0731 (0.0804)  loss_objectness: 0.0123 (0.0190)  loss_rpn_box_reg: 0.0091 (0.0125)  time: 0.9045
# Epoch: [3] Total time: 0:07:34 (0.9094 s / it)
# Epoch:  3 | val acc: 0.8080 | val auc: 0.9194
# Best Epoch:  3 | val acc: 0.8080 | Best val auc: 0.9194
# Epoch: [4]  [  0/500]  eta: 0:17:37  lr: 0.005000  loss: 0.4005 (0.4005)  loss_classifier: 0.1294 (0.1294)  loss_box_reg: 0.0933 (0.0933)  loss_objectness: 0.0999 (0.0999)  loss_rpn_box_reg: 0.0779 (0.0779)  time: 2.1143
# Epoch: [4]  [ 20/500]  eta: 0:07:42  lr: 0.005000  loss: 0.2014 (0.2217)  loss_classifier: 0.1023 (0.1057)  loss_box_reg: 0.0749 (0.0780)  loss_objectness: 0.0150 (0.0193)  loss_rpn_box_reg: 0.0101 (0.0187)  time: 0.9066
# Epoch: [4]  [ 40/500]  eta: 0:07:10  lr: 0.005000  loss: 0.2018 (0.2149)  loss_classifier: 0.0998 (0.1028)  loss_box_reg: 0.0713 (0.0762)  loss_objectness: 0.0147 (0.0193)  loss_rpn_box_reg: 0.0103 (0.0166)  time: 0.9084
# Epoch: [4]  [ 60/500]  eta: 0:06:47  lr: 0.005000  loss: 0.1910 (0.2079)  loss_classifier: 0.0950 (0.1009)  loss_box_reg: 0.0680 (0.0744)  loss_objectness: 0.0121 (0.0179)  loss_rpn_box_reg: 0.0114 (0.0148)  time: 0.9055
# Epoch: [4]  [ 80/500]  eta: 0:06:27  lr: 0.005000  loss: 0.1976 (0.2073)  loss_classifier: 0.0980 (0.1010)  loss_box_reg: 0.0805 (0.0752)  loss_objectness: 0.0123 (0.0172)  loss_rpn_box_reg: 0.0096 (0.0139)  time: 0.9057
# Epoch: [4]  [100/500]  eta: 0:06:07  lr: 0.005000  loss: 0.1894 (0.2063)  loss_classifier: 0.0922 (0.1011)  loss_box_reg: 0.0673 (0.0752)  loss_objectness: 0.0104 (0.0165)  loss_rpn_box_reg: 0.0108 (0.0135)  time: 0.9062
# Epoch: [4]  [120/500]  eta: 0:05:48  lr: 0.005000  loss: 0.2028 (0.2050)  loss_classifier: 0.0970 (0.1007)  loss_box_reg: 0.0704 (0.0751)  loss_objectness: 0.0142 (0.0163)  loss_rpn_box_reg: 0.0101 (0.0131)  time: 0.9066
# Epoch: [4]  [140/500]  eta: 0:05:29  lr: 0.005000  loss: 0.2204 (0.2066)  loss_classifier: 0.1062 (0.1014)  loss_box_reg: 0.0795 (0.0758)  loss_objectness: 0.0104 (0.0161)  loss_rpn_box_reg: 0.0122 (0.0133)  time: 0.9040
# Epoch: [4]  [160/500]  eta: 0:05:10  lr: 0.005000  loss: 0.1971 (0.2079)  loss_classifier: 0.0985 (0.1018)  loss_box_reg: 0.0815 (0.0770)  loss_objectness: 0.0109 (0.0159)  loss_rpn_box_reg: 0.0110 (0.0131)  time: 0.9027
# Epoch: [4]  [180/500]  eta: 0:04:51  lr: 0.005000  loss: 0.1885 (0.2076)  loss_classifier: 0.0925 (0.1019)  loss_box_reg: 0.0735 (0.0768)  loss_objectness: 0.0129 (0.0159)  loss_rpn_box_reg: 0.0109 (0.0130)  time: 0.9051
# Epoch: [4]  [200/500]  eta: 0:04:33  lr: 0.005000  loss: 0.1862 (0.2063)  loss_classifier: 0.0866 (0.1014)  loss_box_reg: 0.0742 (0.0765)  loss_objectness: 0.0110 (0.0157)  loss_rpn_box_reg: 0.0105 (0.0126)  time: 0.9074
# Epoch: [4]  [220/500]  eta: 0:04:15  lr: 0.005000  loss: 0.2047 (0.2077)  loss_classifier: 0.1131 (0.1023)  loss_box_reg: 0.0779 (0.0771)  loss_objectness: 0.0123 (0.0157)  loss_rpn_box_reg: 0.0101 (0.0125)  time: 0.9077
# Epoch: [4]  [240/500]  eta: 0:03:56  lr: 0.005000  loss: 0.1987 (0.2079)  loss_classifier: 0.0999 (0.1028)  loss_box_reg: 0.0775 (0.0774)  loss_objectness: 0.0111 (0.0154)  loss_rpn_box_reg: 0.0089 (0.0124)  time: 0.9084
# Epoch: [4]  [260/500]  eta: 0:03:38  lr: 0.005000  loss: 0.2150 (0.2090)  loss_classifier: 0.1093 (0.1035)  loss_box_reg: 0.0800 (0.0775)  loss_objectness: 0.0153 (0.0153)  loss_rpn_box_reg: 0.0109 (0.0127)  time: 0.9042
# Epoch: [4]  [280/500]  eta: 0:03:20  lr: 0.005000  loss: 0.2113 (0.2086)  loss_classifier: 0.1036 (0.1033)  loss_box_reg: 0.0735 (0.0773)  loss_objectness: 0.0144 (0.0154)  loss_rpn_box_reg: 0.0091 (0.0125)  time: 0.9061
# Epoch: [4]  [300/500]  eta: 0:03:02  lr: 0.005000  loss: 0.1856 (0.2082)  loss_classifier: 0.0937 (0.1033)  loss_box_reg: 0.0733 (0.0770)  loss_objectness: 0.0138 (0.0154)  loss_rpn_box_reg: 0.0117 (0.0125)  time: 0.9057
# Epoch: [4]  [320/500]  eta: 0:02:43  lr: 0.005000  loss: 0.2075 (0.2089)  loss_classifier: 0.1040 (0.1034)  loss_box_reg: 0.0748 (0.0771)  loss_objectness: 0.0174 (0.0158)  loss_rpn_box_reg: 0.0118 (0.0126)  time: 0.9043
# Epoch: [4]  [340/500]  eta: 0:02:25  lr: 0.005000  loss: 0.2000 (0.2090)  loss_classifier: 0.1035 (0.1037)  loss_box_reg: 0.0704 (0.0770)  loss_objectness: 0.0128 (0.0158)  loss_rpn_box_reg: 0.0106 (0.0125)  time: 0.9031
# Epoch: [4]  [360/500]  eta: 0:02:07  lr: 0.005000  loss: 0.1744 (0.2080)  loss_classifier: 0.0840 (0.1032)  loss_box_reg: 0.0544 (0.0765)  loss_objectness: 0.0149 (0.0159)  loss_rpn_box_reg: 0.0096 (0.0124)  time: 0.9087
# Epoch: [4]  [380/500]  eta: 0:01:49  lr: 0.005000  loss: 0.2306 (0.2087)  loss_classifier: 0.1115 (0.1035)  loss_box_reg: 0.0829 (0.0768)  loss_objectness: 0.0142 (0.0160)  loss_rpn_box_reg: 0.0105 (0.0123)  time: 0.9088
# Epoch: [4]  [400/500]  eta: 0:01:30  lr: 0.005000  loss: 0.1996 (0.2086)  loss_classifier: 0.1101 (0.1037)  loss_box_reg: 0.0697 (0.0766)  loss_objectness: 0.0113 (0.0160)  loss_rpn_box_reg: 0.0099 (0.0123)  time: 0.9072
# Epoch: [4]  [420/500]  eta: 0:01:12  lr: 0.005000  loss: 0.2042 (0.2090)  loss_classifier: 0.1025 (0.1039)  loss_box_reg: 0.0808 (0.0768)  loss_objectness: 0.0133 (0.0161)  loss_rpn_box_reg: 0.0103 (0.0123)  time: 0.9064
# Epoch: [4]  [440/500]  eta: 0:00:54  lr: 0.005000  loss: 0.1822 (0.2084)  loss_classifier: 0.0900 (0.1036)  loss_box_reg: 0.0696 (0.0766)  loss_objectness: 0.0114 (0.0160)  loss_rpn_box_reg: 0.0087 (0.0122)  time: 0.9087
# Epoch: [4]  [460/500]  eta: 0:00:36  lr: 0.005000  loss: 0.2059 (0.2088)  loss_classifier: 0.1112 (0.1039)  loss_box_reg: 0.0774 (0.0769)  loss_objectness: 0.0103 (0.0159)  loss_rpn_box_reg: 0.0103 (0.0121)  time: 0.9062
# Epoch: [4]  [480/500]  eta: 0:00:18  lr: 0.005000  loss: 0.2201 (0.2093)  loss_classifier: 0.1201 (0.1045)  loss_box_reg: 0.0740 (0.0769)  loss_objectness: 0.0161 (0.0159)  loss_rpn_box_reg: 0.0091 (0.0120)  time: 0.9047
# Epoch: [4]  [499/500]  eta: 0:00:00  lr: 0.005000  loss: 0.2134 (0.2095)  loss_classifier: 0.1115 (0.1046)  loss_box_reg: 0.0810 (0.0771)  loss_objectness: 0.0107 (0.0158)  loss_rpn_box_reg: 0.0096 (0.0120)  time: 0.9069
# Epoch: [4] Total time: 0:07:34 (0.9089 s / it)
# Epoch:  4 | val acc: 0.7960 | val auc: 0.9177
# Epoch: [5]  [  0/500]  eta: 0:17:31  lr: 0.000500  loss: 0.1997 (0.1997)  loss_classifier: 0.1122 (0.1122)  loss_box_reg: 0.0716 (0.0716)  loss_objectness: 0.0079 (0.0079)  loss_rpn_box_reg: 0.0080 (0.0080)  time: 2.1038
# Epoch: [5]  [ 20/500]  eta: 0:07:42  lr: 0.000500  loss: 0.1812 (0.1870)  loss_classifier: 0.0912 (0.0956)  loss_box_reg: 0.0703 (0.0689)  loss_objectness: 0.0094 (0.0121)  loss_rpn_box_reg: 0.0112 (0.0104)  time: 0.9072
# Epoch: [5]  [ 40/500]  eta: 0:07:11  lr: 0.000500  loss: 0.1739 (0.1883)  loss_classifier: 0.0903 (0.0962)  loss_box_reg: 0.0637 (0.0690)  loss_objectness: 0.0135 (0.0124)  loss_rpn_box_reg: 0.0095 (0.0106)  time: 0.9098
# Epoch: [5]  [ 60/500]  eta: 0:06:48  lr: 0.000500  loss: 0.1754 (0.1877)  loss_classifier: 0.0927 (0.0950)  loss_box_reg: 0.0692 (0.0707)  loss_objectness: 0.0092 (0.0116)  loss_rpn_box_reg: 0.0085 (0.0104)  time: 0.9061
# Epoch: [5]  [ 80/500]  eta: 0:06:27  lr: 0.000500  loss: 0.1950 (0.1923)  loss_classifier: 0.0973 (0.0969)  loss_box_reg: 0.0793 (0.0725)  loss_objectness: 0.0133 (0.0120)  loss_rpn_box_reg: 0.0118 (0.0108)  time: 0.9076
# Epoch: [5]  [100/500]  eta: 0:06:07  lr: 0.000500  loss: 0.1680 (0.1880)  loss_classifier: 0.0836 (0.0949)  loss_box_reg: 0.0645 (0.0710)  loss_objectness: 0.0072 (0.0114)  loss_rpn_box_reg: 0.0095 (0.0107)  time: 0.9058
# Epoch: [5]  [120/500]  eta: 0:05:48  lr: 0.000500  loss: 0.1747 (0.1877)  loss_classifier: 0.0881 (0.0944)  loss_box_reg: 0.0634 (0.0704)  loss_objectness: 0.0114 (0.0115)  loss_rpn_box_reg: 0.0095 (0.0113)  time: 0.9063
# Epoch: [5]  [140/500]  eta: 0:05:29  lr: 0.000500  loss: 0.1815 (0.1875)  loss_classifier: 0.0889 (0.0943)  loss_box_reg: 0.0712 (0.0704)  loss_objectness: 0.0100 (0.0116)  loss_rpn_box_reg: 0.0096 (0.0112)  time: 0.9071
# Epoch: [5]  [160/500]  eta: 0:05:10  lr: 0.000500  loss: 0.1871 (0.1869)  loss_classifier: 0.0954 (0.0941)  loss_box_reg: 0.0643 (0.0701)  loss_objectness: 0.0092 (0.0116)  loss_rpn_box_reg: 0.0093 (0.0111)  time: 0.9082
# Epoch: [5]  [180/500]  eta: 0:04:52  lr: 0.000500  loss: 0.1445 (0.1832)  loss_classifier: 0.0736 (0.0924)  loss_box_reg: 0.0578 (0.0689)  loss_objectness: 0.0065 (0.0111)  loss_rpn_box_reg: 0.0081 (0.0109)  time: 0.9061
# Epoch: [5]  [200/500]  eta: 0:04:33  lr: 0.000500  loss: 0.1904 (0.1835)  loss_classifier: 0.0899 (0.0923)  loss_box_reg: 0.0669 (0.0694)  loss_objectness: 0.0083 (0.0110)  loss_rpn_box_reg: 0.0106 (0.0109)  time: 0.9063
# Epoch: [5]  [220/500]  eta: 0:04:15  lr: 0.000500  loss: 0.1895 (0.1843)  loss_classifier: 0.0914 (0.0925)  loss_box_reg: 0.0713 (0.0697)  loss_objectness: 0.0103 (0.0112)  loss_rpn_box_reg: 0.0108 (0.0109)  time: 0.9064
# Epoch: [5]  [240/500]  eta: 0:03:57  lr: 0.000500  loss: 0.1614 (0.1840)  loss_classifier: 0.0879 (0.0926)  loss_box_reg: 0.0612 (0.0696)  loss_objectness: 0.0066 (0.0110)  loss_rpn_box_reg: 0.0099 (0.0108)  time: 0.9058
# Epoch: [5]  [260/500]  eta: 0:03:38  lr: 0.000500  loss: 0.1692 (0.1838)  loss_classifier: 0.0855 (0.0925)  loss_box_reg: 0.0666 (0.0697)  loss_objectness: 0.0075 (0.0109)  loss_rpn_box_reg: 0.0091 (0.0108)  time: 0.9024
# Epoch: [5]  [280/500]  eta: 0:03:20  lr: 0.000500  loss: 0.1806 (0.1843)  loss_classifier: 0.0976 (0.0926)  loss_box_reg: 0.0707 (0.0698)  loss_objectness: 0.0100 (0.0110)  loss_rpn_box_reg: 0.0118 (0.0109)  time: 0.9056
# Epoch: [5]  [300/500]  eta: 0:03:02  lr: 0.000500  loss: 0.1388 (0.1819)  loss_classifier: 0.0750 (0.0915)  loss_box_reg: 0.0541 (0.0689)  loss_objectness: 0.0073 (0.0108)  loss_rpn_box_reg: 0.0073 (0.0107)  time: 0.9042
# Epoch: [5]  [320/500]  eta: 0:02:43  lr: 0.000500  loss: 0.1745 (0.1812)  loss_classifier: 0.0839 (0.0911)  loss_box_reg: 0.0688 (0.0687)  loss_objectness: 0.0065 (0.0107)  loss_rpn_box_reg: 0.0082 (0.0107)  time: 0.9054
# Epoch: [5]  [340/500]  eta: 0:02:25  lr: 0.000500  loss: 0.1670 (0.1810)  loss_classifier: 0.0806 (0.0908)  loss_box_reg: 0.0696 (0.0688)  loss_objectness: 0.0068 (0.0106)  loss_rpn_box_reg: 0.0084 (0.0107)  time: 0.9075
# Epoch: [5]  [360/500]  eta: 0:02:07  lr: 0.000500  loss: 0.1527 (0.1796)  loss_classifier: 0.0734 (0.0902)  loss_box_reg: 0.0579 (0.0683)  loss_objectness: 0.0062 (0.0105)  loss_rpn_box_reg: 0.0084 (0.0107)  time: 0.9064
# Epoch: [5]  [380/500]  eta: 0:01:49  lr: 0.000500  loss: 0.1519 (0.1788)  loss_classifier: 0.0736 (0.0896)  loss_box_reg: 0.0608 (0.0681)  loss_objectness: 0.0064 (0.0105)  loss_rpn_box_reg: 0.0096 (0.0107)  time: 0.9033
# Epoch: [5]  [400/500]  eta: 0:01:30  lr: 0.000500  loss: 0.1562 (0.1781)  loss_classifier: 0.0819 (0.0892)  loss_box_reg: 0.0621 (0.0677)  loss_objectness: 0.0079 (0.0105)  loss_rpn_box_reg: 0.0091 (0.0107)  time: 0.9065
# Epoch: [5]  [420/500]  eta: 0:01:12  lr: 0.000500  loss: 0.1748 (0.1782)  loss_classifier: 0.0904 (0.0894)  loss_box_reg: 0.0682 (0.0677)  loss_objectness: 0.0090 (0.0104)  loss_rpn_box_reg: 0.0089 (0.0106)  time: 0.9059
# Epoch: [5]  [440/500]  eta: 0:00:54  lr: 0.000500  loss: 0.1633 (0.1779)  loss_classifier: 0.0802 (0.0892)  loss_box_reg: 0.0662 (0.0677)  loss_objectness: 0.0073 (0.0104)  loss_rpn_box_reg: 0.0088 (0.0106)  time: 0.9057
# Epoch: [5]  [460/500]  eta: 0:00:36  lr: 0.000500  loss: 0.1871 (0.1783)  loss_classifier: 0.0860 (0.0892)  loss_box_reg: 0.0676 (0.0679)  loss_objectness: 0.0080 (0.0105)  loss_rpn_box_reg: 0.0107 (0.0107)  time: 0.9063
# Epoch: [5]  [480/500]  eta: 0:00:18  lr: 0.000500  loss: 0.1576 (0.1782)  loss_classifier: 0.0745 (0.0889)  loss_box_reg: 0.0614 (0.0679)  loss_objectness: 0.0064 (0.0105)  loss_rpn_box_reg: 0.0085 (0.0110)  time: 0.9086
# Epoch: [5]  [499/500]  eta: 0:00:00  lr: 0.000500  loss: 0.1779 (0.1787)  loss_classifier: 0.0856 (0.0891)  loss_box_reg: 0.0686 (0.0681)  loss_objectness: 0.0084 (0.0106)  loss_rpn_box_reg: 0.0096 (0.0110)  time: 0.9067
# Epoch: [5] Total time: 0:07:34 (0.9090 s / it)
# Epoch:  5 | val acc: 0.7760 | val auc: 0.9273
# Best Epoch:  5 | val acc: 0.7760 | Best val auc: 0.9273
# Epoch: [6]  [  0/500]  eta: 0:18:05  lr: 0.000500  loss: 0.2042 (0.2042)  loss_classifier: 0.1108 (0.1108)  loss_box_reg: 0.0763 (0.0763)  loss_objectness: 0.0072 (0.0072)  loss_rpn_box_reg: 0.0099 (0.0099)  time: 2.1709
# Epoch: [6]  [ 20/500]  eta: 0:07:44  lr: 0.000500  loss: 0.1563 (0.1694)  loss_classifier: 0.0724 (0.0813)  loss_box_reg: 0.0615 (0.0659)  loss_objectness: 0.0064 (0.0105)  loss_rpn_box_reg: 0.0081 (0.0118)  time: 0.9079
# Epoch: [6]  [ 40/500]  eta: 0:07:11  lr: 0.000500  loss: 0.1741 (0.1738)  loss_classifier: 0.0867 (0.0862)  loss_box_reg: 0.0678 (0.0669)  loss_objectness: 0.0076 (0.0100)  loss_rpn_box_reg: 0.0091 (0.0108)  time: 0.9076
# Epoch: [6]  [ 60/500]  eta: 0:06:48  lr: 0.000500  loss: 0.1595 (0.1732)  loss_classifier: 0.0739 (0.0844)  loss_box_reg: 0.0623 (0.0672)  loss_objectness: 0.0081 (0.0098)  loss_rpn_box_reg: 0.0103 (0.0118)  time: 0.9091
# Epoch: [6]  [ 80/500]  eta: 0:06:27  lr: 0.000500  loss: 0.1724 (0.1713)  loss_classifier: 0.0883 (0.0843)  loss_box_reg: 0.0603 (0.0656)  loss_objectness: 0.0074 (0.0099)  loss_rpn_box_reg: 0.0108 (0.0114)  time: 0.9062
# Epoch: [6]  [100/500]  eta: 0:06:08  lr: 0.000500  loss: 0.1766 (0.1727)  loss_classifier: 0.0805 (0.0846)  loss_box_reg: 0.0782 (0.0668)  loss_objectness: 0.0068 (0.0098)  loss_rpn_box_reg: 0.0100 (0.0116)  time: 0.9068
# Epoch: [6]  [120/500]  eta: 0:05:48  lr: 0.000500  loss: 0.1526 (0.1712)  loss_classifier: 0.0703 (0.0835)  loss_box_reg: 0.0671 (0.0667)  loss_objectness: 0.0052 (0.0097)  loss_rpn_box_reg: 0.0094 (0.0114)  time: 0.9070
# Epoch: [6]  [140/500]  eta: 0:05:29  lr: 0.000500  loss: 0.1584 (0.1699)  loss_classifier: 0.0756 (0.0826)  loss_box_reg: 0.0649 (0.0664)  loss_objectness: 0.0073 (0.0096)  loss_rpn_box_reg: 0.0096 (0.0115)  time: 0.9077
# Epoch: [6]  [160/500]  eta: 0:05:11  lr: 0.000500  loss: 0.1545 (0.1689)  loss_classifier: 0.0759 (0.0823)  loss_box_reg: 0.0565 (0.0656)  loss_objectness: 0.0072 (0.0097)  loss_rpn_box_reg: 0.0092 (0.0113)  time: 0.9038
# Epoch: [6]  [180/500]  eta: 0:04:52  lr: 0.000500  loss: 0.1702 (0.1689)  loss_classifier: 0.0785 (0.0825)  loss_box_reg: 0.0591 (0.0653)  loss_objectness: 0.0089 (0.0098)  loss_rpn_box_reg: 0.0097 (0.0113)  time: 0.9069
# Epoch: [6]  [200/500]  eta: 0:04:33  lr: 0.000500  loss: 0.1683 (0.1693)  loss_classifier: 0.0816 (0.0827)  loss_box_reg: 0.0639 (0.0654)  loss_objectness: 0.0077 (0.0098)  loss_rpn_box_reg: 0.0103 (0.0113)  time: 0.9054
# Epoch: [6]  [220/500]  eta: 0:04:15  lr: 0.000500  loss: 0.1672 (0.1694)  loss_classifier: 0.0840 (0.0829)  loss_box_reg: 0.0645 (0.0655)  loss_objectness: 0.0084 (0.0097)  loss_rpn_box_reg: 0.0090 (0.0113)  time: 0.9095
# Epoch: [6]  [240/500]  eta: 0:03:57  lr: 0.000500  loss: 0.1509 (0.1691)  loss_classifier: 0.0750 (0.0830)  loss_box_reg: 0.0570 (0.0652)  loss_objectness: 0.0087 (0.0097)  loss_rpn_box_reg: 0.0106 (0.0112)  time: 0.9071
# Epoch: [6]  [260/500]  eta: 0:03:38  lr: 0.000500  loss: 0.1717 (0.1699)  loss_classifier: 0.0833 (0.0833)  loss_box_reg: 0.0670 (0.0657)  loss_objectness: 0.0068 (0.0097)  loss_rpn_box_reg: 0.0105 (0.0112)  time: 0.9082
# Epoch: [6]  [280/500]  eta: 0:03:20  lr: 0.000500  loss: 0.1576 (0.1695)  loss_classifier: 0.0796 (0.0832)  loss_box_reg: 0.0591 (0.0655)  loss_objectness: 0.0087 (0.0097)  loss_rpn_box_reg: 0.0096 (0.0111)  time: 0.9070
# Epoch: [6]  [300/500]  eta: 0:03:02  lr: 0.000500  loss: 0.1512 (0.1691)  loss_classifier: 0.0730 (0.0831)  loss_box_reg: 0.0570 (0.0654)  loss_objectness: 0.0061 (0.0096)  loss_rpn_box_reg: 0.0093 (0.0111)  time: 0.9081
# Epoch: [6]  [320/500]  eta: 0:02:44  lr: 0.000500  loss: 0.1618 (0.1693)  loss_classifier: 0.0827 (0.0833)  loss_box_reg: 0.0650 (0.0655)  loss_objectness: 0.0069 (0.0095)  loss_rpn_box_reg: 0.0095 (0.0110)  time: 0.9086
# Epoch: [6]  [340/500]  eta: 0:02:25  lr: 0.000500  loss: 0.1517 (0.1687)  loss_classifier: 0.0796 (0.0830)  loss_box_reg: 0.0615 (0.0654)  loss_objectness: 0.0062 (0.0094)  loss_rpn_box_reg: 0.0090 (0.0109)  time: 0.9091
# Epoch: [6]  [360/500]  eta: 0:02:07  lr: 0.000500  loss: 0.1527 (0.1684)  loss_classifier: 0.0730 (0.0828)  loss_box_reg: 0.0610 (0.0654)  loss_objectness: 0.0063 (0.0093)  loss_rpn_box_reg: 0.0086 (0.0108)  time: 0.9089
# Epoch: [6]  [380/500]  eta: 0:01:49  lr: 0.000500  loss: 0.1415 (0.1677)  loss_classifier: 0.0656 (0.0826)  loss_box_reg: 0.0537 (0.0651)  loss_objectness: 0.0069 (0.0093)  loss_rpn_box_reg: 0.0076 (0.0107)  time: 0.9089
# Epoch: [6]  [400/500]  eta: 0:01:31  lr: 0.000500  loss: 0.1513 (0.1675)  loss_classifier: 0.0776 (0.0825)  loss_box_reg: 0.0586 (0.0649)  loss_objectness: 0.0094 (0.0093)  loss_rpn_box_reg: 0.0097 (0.0108)  time: 0.9087
# Epoch: [6]  [420/500]  eta: 0:01:12  lr: 0.000500  loss: 0.1495 (0.1669)  loss_classifier: 0.0754 (0.0823)  loss_box_reg: 0.0519 (0.0645)  loss_objectness: 0.0072 (0.0093)  loss_rpn_box_reg: 0.0088 (0.0108)  time: 0.9095
# Epoch: [6]  [440/500]  eta: 0:00:54  lr: 0.000500  loss: 0.1668 (0.1673)  loss_classifier: 0.0795 (0.0824)  loss_box_reg: 0.0705 (0.0648)  loss_objectness: 0.0075 (0.0093)  loss_rpn_box_reg: 0.0106 (0.0108)  time: 0.9065
# Epoch: [6]  [460/500]  eta: 0:00:36  lr: 0.000500  loss: 0.1759 (0.1679)  loss_classifier: 0.0824 (0.0827)  loss_box_reg: 0.0719 (0.0651)  loss_objectness: 0.0078 (0.0093)  loss_rpn_box_reg: 0.0099 (0.0108)  time: 0.9096
# Epoch: [6]  [480/500]  eta: 0:00:18  lr: 0.000500  loss: 0.1655 (0.1678)  loss_classifier: 0.0825 (0.0827)  loss_box_reg: 0.0642 (0.0650)  loss_objectness: 0.0082 (0.0094)  loss_rpn_box_reg: 0.0093 (0.0107)  time: 0.9068
# Epoch: [6]  [499/500]  eta: 0:00:00  lr: 0.000500  loss: 0.1560 (0.1676)  loss_classifier: 0.0723 (0.0825)  loss_box_reg: 0.0655 (0.0651)  loss_objectness: 0.0075 (0.0094)  loss_rpn_box_reg: 0.0106 (0.0107)  time: 0.9066
# Epoch: [6] Total time: 0:07:35 (0.9105 s / it)
# Epoch:  6 | val acc: 0.7840 | val auc: 0.9251

# %% [markdown]
# ## Evaluation

# %%
model = _get_instance_segmentation_model(num_classes)
model.to(device)
model.load_state_dict(torch.load("model.pt"))

model.eval()

preds = []
labels = []
locs = []

for image, label, width, height in tqdm(data_loader_val):
    
    image = list(img.to(device) for img in image)
    labels.append(label[-1])
    
    outputs = model(image)
    
    center_points = []
    center_points_preds = []
    
    if len(outputs[-1]['boxes']) == 0:
        preds.append(0)
        center_points.append([])
        center_points_preds.append('')
        locs.append('')
    else:
        preds.append(torch.max(outputs[-1]['scores']).tolist())
        
        new_output_index = torch.where((outputs[-1]['scores']>0.1))
        new_boxes = outputs[-1]['boxes'][new_output_index]
        new_scores = outputs[-1]['scores'][new_output_index]
        
        for i in range(len(new_boxes)):
            new_box = new_boxes[i].tolist()
            center_x = (new_box[0] + new_box[2])/2
            center_y = (new_box[1] + new_box[3])/2
            center_points.append([center_x/600 * width[-1],center_y/600 * height[-1]])
        center_points_preds += new_scores.tolist()
        
        line = ''
        for i in range(len(new_boxes)):
            if i == len(new_boxes)-1:
                line += str(center_points_preds[i]) + ' ' + str(center_points[i][0]) + ' ' + str(center_points[i][1])
            else:
                line += str(center_points_preds[i]) + ' ' + str(center_points[i][0]) + ' ' + str(center_points[i][1]) +';'
        locs.append(line)

cls_res = pd.DataFrame({'image_name': dataset_dev.image_files_list, 'prediction': preds})
cls_res.to_csv('classification.csv', columns=['image_name', 'prediction'], sep=',', index=None)
print('classification.csv generated.')

loc_res = pd.DataFrame({'image_name': dataset_dev.image_files_list, 'prediction': locs})
loc_res.to_csv('localization.csv', columns=['image_name', 'prediction'], sep=',', index=None)
print('localization.csv generated.')
# Out:
# 100%|██████████| 1000/1000 [00:52<00:00, 18.87it/s]
# classification.csv generated.
# localization.csv generated.

# %% [markdown]
# ## Calculate FROC

# %%
# !wget "https://raw.githubusercontent.com/jfhealthcare/object-CXR/master/froc.py"

# %%
# %run froc.py $root"dev.csv" "localization.csv"
# Out:
# False positives per image:
# 0.125	0.25	0.5	1	2	4	8
# Sensitivity:
# 0.576	0.707	0.798	0.859	0.892	0.892	0.892
# FROC:
# 0.8022519352568613
